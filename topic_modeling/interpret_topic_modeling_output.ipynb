# %% [markdown]
# ### This notebook looks at the topics (in terms of top words and top documents) for each topic, to enable interpretation for each topic uncovered by various topic models trained and saved in train_mallet_on_combined_article_text_data.py

# %%
import little_mallet_wrapper as lmw
import pandas as pd

# %%
MALLET_OUTPUT_PATH = '/home/pranavgoel/mallet_output/trans_fer_entropy_first_full_data_tm'

# %%
combined_df = pd.read_csv('all_texts_combined.csv')

# %%
titles_and_texts = list(zip(combined_df['title'], 
                            combined_df['text']))

titles_and_texts = list(map(lambda x:x[0] + '\n\n\n' + x[1], 
                            titles_and_texts))

# %%
def display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts, 
                                                          topic_keys, 
                                                          topic_distributions, 
                                                          topic_ind, 
                                                          num_top_words = 20,
                                                          num_top_docs = 5):
    print('Topic ' + str(topic_ind))
    print('\nTop words:\n' + ', '.join(topic_keys[topic_ind][:num_top_words]))
    print('\n\nTop documents: ')
    top_doc_ind = 0
    for _, d in lmw.get_top_docs(titles_and_texts, topic_distributions, topic_index=topic_ind, n=num_top_docs):
        print(str(top_doc_ind+1) + '. ' + d[:2000] + '.........')
        print('\n=== ===\n')
        top_doc_ind += 1

# %% [markdown]
# #### Looking at top words and documents for each topic for the mallet model with K=10

# %%
num_topics = 10

# %%
topic_keys = lmw.load_topic_keys(MALLET_OUTPUT_PATH + '/mallet.topic_keys.' + str(num_topics))

# %%
topic_distributions = lmw.load_topic_distributions(MALLET_OUTPUT_PATH + '/mallet.topic_distributions.' + str(num_topics))

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      0)
# Out:
# Topic 0
#
# Top words:
# health, new, also, year, may, million, said, one, market, use, years, help, people, research, data, high, work, china, risk, services
#
#
# Top documents:
# 1. SKRR Exploration Inc. Grants Stock Options
#
#
# VANCOUVER, BC, April 13, 2023 /CNW/ - SKRR Exploration Inc. (TSXV: SKRR) (FSE: B04Q) ("SKRR" or the "Company") announces the granting of incentive stock options ("Options") to certain of its directors, officers and consultants to purchase up to an aggregate 1,015,000 common shares of the Company at a price of $0.08 per common share for a period of three (3) years. The Options vest on the date of grant.
#
# SKRR Exploration Inc. Logo (CNW Group/SKRR EXPLORATION INC.)
#
# About SKRR Exploration Inc.:
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      1)
# Out:
# Topic 1
#
# Top words:
# cells, fig, cell, using, expression, protein, mice, data, gene, analysis, genes, used, supplementary, cancer, also, patients, performed, levels, control, treatment
#
#
# Top documents:
# 1. MEK1/2 regulate normal BCR and ABL1 tumor-suppressor functions to dictate ATO response in TKI-resistant Ph+ leukemia
#
#
# MEK1/2 inhibition synergizes with ATO to induce cytotoxicity in TKIs-resistant Ph+ leukemic cells
#
# We first analyzed the pharmacologic interactions between the MEKi Mirdametinib (PD0325901; indicated as PD) and ATO using a fixed-ratio experimental design on Ph+ leukemia cell lines displaying different degrees of resistance to the first, second, and third generation of BCR::ABL1 TKIs [20, 21].
#
# Combined treatment of cells with PD plus ATO resulted in the synergistic induction of apoptosis in all the tested cell lines, regardless of their sensitivity to TKIs (Fig. 1A and Supplementary Fig. 1A).
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      2)
# Out:
# Topic 2
#
# Top words:
# transgender, gender, said, care, state, bill, would, law, affirming, children, trans, ban, women, house, health, people, medical, sports, states, bills
#
#
# Top documents:
# 1. US would bar full ban on trans athletes but allow exceptions
#
#
# Schools and colleges would be forbidden from enacting out right bans, but teams could create limits in certain cases.
#
# Example video title will go here for this video
#
# WASHINGTON — Schools and colleges across the U.S. would be forbidden from enacting outright bans on transgender athletes under a proposal released Thursday from the Biden administration, but teams could create some limits in certain cases — for example, to ensure fairness.
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      3)
# Out:
# Topic 3
#
# Top words:
# pride, drag, city, june, community, new, event, san, year, center, com, events, art, also, queer, first, www, org, may, lgbtq
#
#
# Top documents:
# 1. Going Out, May 4-12, 2023
#
#
# Come what May, this month's first week is blooming with intriguing arts and nightlife events.
#
# '1776' @ San Jose Center for Performing Arts ARTS
#
# (Click here for listings of LGBTQ movies, TV series, podcasts and community organizations.)
#
#
#
# DANCE, OPERA, THEATER
#
# 1776 @ San Jose Center for Performing Arts
#
# The classic musical about the signing of the Declaration of Independence is given a modern feminist twist in the Broadway touring production. $38-$88. May 16-21. 255 Almaden Blvd. https://broadwaysanjose.com/
#
#
#
# The Canterville Ghost @ New Conservatory Theatre Center
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      4)
# Out:
# Topic 4
#
# Top words:
# said, school, students, district, police, board, county, parents, student, told, year, according, public, news, one, brown, schools, would, children, transgender
#
#
# Top documents:
# 1. Missouri man facing execution for killing 2 jailers in failed bid to help inmate escape in 2000
#
#
# BONNE TERRE, Mo. — A Missouri man who shot and killed two jailers nearly 23 years ago during a failed bid to help an acquaintance escape from a rural jail was executed Tuesday evening.
#
# Michael Tisius, 42, received a lethal injection of pentobarbital at the state prison in Bonne Terre and was pronounced dead at 6:10 p.m., authorities said. He was convicted of the June 22, 2000, killings of Leon Egley and Jason Acton at the small Randolph County Jail.
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      5)
# Out:
# Topic 5
#
# Top words:
# fig, supplementary, data, using, two, model, used, size, also, different, time, reaction, image, high, based, full, surface, table, one, species
#
#
# Top documents:
# 1. Active-site isolation in intermetallics enables precise identification of elementary reaction kinetics during olefin hydrogenation
#
#
# Ethylene hydrogenation kinetics on Pd 9 Zn 43
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      6)
# Out:
# Topic 6
#
# Top words:
# like, people, one, know, time, think, trans, said, really, get, going, want, would, way, even, life, women, new, much, lot
#
#
# Top documents:
# 1. He Ghosted. I’m Grateful.
#
#
# This transcript was created using speech recognition software. While it has been reviewed by human transcribers, it may contain errors. Please review the episode audio before quoting from this transcript and email transcripts@nytimes.com with any questions.
#
# anna martin
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      7)
# Out:
# Topic 7
#
# Top words:
# light, bud, said, pride, company, mulvaney, target, beer, busch, anheuser, twitter, sales, brand, lgbtq, transgender, backlash, media, dylan, month, social
#
#
# Top documents:
# 1. Pride becomes a minefield for big companies, but many continue their support
#
#
# Many big companies, including Target and Bud Light’s parent, are still backing Pride events in June despite the minefield that the monthlong celebration has become for some of them.
#
# Target and Bud Light recently came under fire for their efforts to appeal to the LGBTQ+ community, only to come under more fire when they tried to backpedal.
#
# But even as they battle the negative publicity, Target and Bud Light haven’t pulled away from this year’s Pride celebrations. Target is a platinum sponsor of NYC Pride, which requires a $175,000 donation. And Bud Light’s parent Anheuser-Busch is a sponsor of Pride celebrations in Chicago, San Francisco, Charlotte and elsewhere.
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      8)
# Out:
# Topic 8
#
# Top words:
# people, lgbtq, said, community, rights, gender, anti, trans, gay, transgender, also, sex, hate, support, court, sexual, one, public, law, new
#
#
# Top documents:
# 1. Supreme Court rules for a designer who doesn't want to make wedding websites for gay couples; Quad City Area LGBTQ community reacts
#
#
# WASHINGTON (AP) — In a defeat for gay rights, the Supreme Court’s conservative majority ruled on Friday that a Christian graphic artist who wants to design wedding websites can refuse to work with same-sex couples. One of the court’s liberal justices wrote in a dissent that the decision’s effect is to “mark gays and lesbians for second-class status” and that the decision opens the door to other discrimination.
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      9)
# Out:
# Topic 9
#
# Top words:
# trump, state, desantis, president, said, republican, biden, house, florida, republicans, former, would, political, party, new, campaign, gop, election, democrats, one
#
#
# Top documents:
# 1. Former vice president Mike Pence files paperwork launching 2024 presidential bid
#
#
# Former Vice President Mike Pence filed paperwork on Monday declaring his campaign for president in 2024, setting up a challenge to his former boss, Donald Trump, just two years after their time in the White House ended with an insurrection at the U.S. Capitol and Pence fleeing for his life.
#
# Pence, the nation's 48th vice president, will formally launch his bid for the Republican nomination with a video and kickoff event in Des Moines, Iowa, on Wednesday, which is his 64th birthday, according to people familiar with his plans. He made his candidacy official Monday with the Federal Election Commission.
#
# ...

# %% [markdown]
# #### Looking at top words and documents for each topic for the mallet model with K=20

# %%
num_topics = 20
topic_keys = lmw.load_topic_keys(MALLET_OUTPUT_PATH + '/mallet.topic_keys.' + str(num_topics))
topic_distributions = lmw.load_topic_distributions(MALLET_OUTPUT_PATH + '/mallet.topic_distributions.' + str(num_topics))

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      0)
# Out:
# Topic 0
#
# Top words:
# women, sports, transgender, athletes, girls, trans, said, female, would, school, biological, teams, male, men, gaines, team, ohio, title, compete, students
#
#
# Top documents:
# 1. 'Start Taking a Knee': Former US Olympian Calls for Protests Against UCI's Trans Cyclist Policy
#
#
# A former three-time U.S. Olympian is calling on cyclists to take a knee at the start line in protest of the world’s cycling governing body’s decision to allow trans cyclists to compete in the female category.
#
# Inga Thompson, a road cyclist for Team USA, took to Twitter Sunday after a week filled with controversy following trans cyclist Austin Killips’ “victory” in the Tour of the Gila overall category against female riders last week.
#
# “It is time for Women Cyclist to start protesting @UCI_cycling Policy,” Thompson tweeted. “Start taking a knee at the starting lines. Team managers need to speak up and protect their riders. Hold signs at every race ‘Save Women’s Sports.’”
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      1)
# Out:
# Topic 1
#
# Top words:
# cells, fig, cell, expression, protein, mice, cancer, also, levels, tumor, treatment, patients, supplementary, induced, gene, increased, associated, genes, activation, binding
#
#
# Top documents:
# 1. P38 kinase in gastrointestinal cancers
#
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      2)
# Out:
# Topic 2
#
# Top words:
# like, people, said, one, know, think, get, going, would, really, time, want, trans, way, lot, even, see, make, says, say
#
#
# Top documents:
# 1. He Ghosted. I’m Grateful.
#
#
# This transcript was created using speech recognition software. While it has been reviewed by human transcribers, it may contain errors. Please review the episode audio before quoting from this transcript and email transcripts@nytimes.com with any questions.
#
# anna martin
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      3)
# Out:
# Topic 3
#
# Top words:
# june, www, com, org, https, art, center, may, park, san, music, free, beach, april, saturday, los, angeles, new, museum, also
#
#
# Top documents:
# 1. Going Out, May 4-12, 2023
#
#
# Come what May, this month's first week is blooming with intriguing arts and nightlife events.
#
# '1776' @ San Jose Center for Performing Arts ARTS
#
# (Click here for listings of LGBTQ movies, TV series, podcasts and community organizations.)
#
#
#
# DANCE, OPERA, THEATER
#
# 1776 @ San Jose Center for Performing Arts
#
# The classic musical about the signing of the Declaration of Independence is given a modern feminist twist in the Broadway touring production. $38-$88. May 16-21. 255 Almaden Blvd. https://broadwaysanjose.com/
#
#
#
# The Canterville Ghost @ New Conservatory Theatre Center
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      4)
# Out:
# Topic 4
#
# Top words:
# trump, desantis, state, house, said, republican, republicans, president, florida, biden, gop, former, democrats, party, zephyr, campaign, democratic, governor, would, election
#
#
# Top documents:
# 1. Former Vice President Pence filing paperwork launching 2024 presidential bid in challenge to Trump
#
#
# FILE - Former Vice President Mike Pence talks with local residents during a meet and greet on May 23, 2023, in Des Moines, Iowa. Pence will officially launch his widely expected campaign for the Republican nomination for president in Iowa on June 7. (AP Photo/Charlie Neibergall)
#
# NEW YORK – Former Vice President Mike Pence filed paperwork on Monday declaring his campaign for president in 2024, setting up a challenge to his former boss, Donald Trump, just two years after their time in the White House ended with an insurrection at the U.S. Capitol and Pence fleeing for his life.
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      5)
# Out:
# Topic 5
#
# Top words:
# school, students, said, parents, schools, board, education, student, district, gender, children, teachers, public, books, policy, also, university, state, identity, college
#
#
# Top documents:
# 1. Using 'he/him,' 'she/her' in emails got 2 dorm directors fired at small New York Christian college
#
#
# This screenshot of a YouTube interview on April 22, 2023, from user Malcolm Davon Smith, shows former Houghton University employees Raegan Zelaya, left, and Shua Wilmot after they were fired from the school. (Malcolm Davon Smith via AP)
#
# NEW YORK – Shua Wilmot and Raegan Zelaya, two former dorm directors at a small Christian university in western New York, acknowledge their names are unconventional, which explains why they attached gender identities to their work email signatures.
#
# Wilmot uses “he/him.” Zelaya goes by “she/her.”
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      6)
# Out:
# Topic 6
#
# Top words:
# light, bud, mulvaney, company, target, said, beer, busch, anheuser, sales, brand, pride, dylan, backlash, transgender, month, marketing, year, boycott, influencer
#
#
# Top documents:
# 1. Bud Light, top U.S. seller since 2001, loses sales crown to Modelo as backlash continues
#
#
# After more than two decades as America's best-selling beer, Bud Light has slipped into second place.
#
# What You Need To Know After more than two decades as America's best-selling beer, Bud Light has slipped into second place
#
#
#
# Mexican lager Modelo Especial overtook Bud Light in U.S. retail dollar sales in the month ending June 3, according to Bump Williams Consulting
#
#
#
# Modelo controlled 8.4% of U.S. grocery, convenience and liquor store sales; Bud Light fell to 7.3%
#
#
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      7)
# Out:
# Topic 7
#
# Top words:
# said, police, brown, shooting, year, city, attorney, crime, violence, according, man, office, san, prison, department, security, county, report, told, killed
#
#
# Top documents:
# 1. No Charges For Security Guard Who Fatally Shot Alleged Walgreens Shoplifter
#
#
# The security guard who shot and killed Banko Brown, a 24-year-old transgender man suspected of shoplifting at a Walgreens in San Francisco, won't face charges.
#
# On Monday (May 15), the San Francisco DA's office released surveillance video of the moments surrounding Brown's death amid their decision to not pursue charges, per CNN.
#
# “Based on the criminal investigation, review of evidence, and evaluation of the case, we have determined that there is insufficient evidence to support the filing of criminal charges against the suspect in the Banko Brown death investigation,” the DA's office said in a statement.
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      8)
# Out:
# Topic 8
#
# Top words:
# gender, care, bill, transgender, state, said, affirming, law, children, would, people, ban, medical, health, trans, states, bills, minors, legislation, texas
#
#
# Top documents:
# 1. Missouri governor signs bill banning gender-affirming care for transgender minors, some adults
#
#
# FILE - Glenda Starke wears a transgender flag as a counter protest during a rally in favor of a ban on gender-affirming health care legislation, March 20, 2023, at the Missouri Statehouse in Jefferson City, Mo. Transgender minors and some adults in Missouri will soon be banned from accessing puberty blockers, hormones and gender-affirming surgeries under a bill signed Wednesday, June 7, 2003, by the state's Republican governor. (AP Photo/Charlie Riedel, File)
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      9)
# Out:
# Topic 9
#
# Top words:
# data, model, using, used, fig, study, based, models, analysis, time, two, also, different, species, one, across, results, number, within, may
#
#
# Top documents:
# 1. Hemispheric asymmetries and brain size in mammals
#
#
# Overall, six meta-regressions were calculated (ambilaterality, leftward lateralization, and rightward lateralization, each with adult brain mass in g and neuron number as predictors). Data were collected from 28 different species (Table 1). Brain size data were available for all 28 species, neuron number data for only 17 species. Brain size and neuron number were significantly correlated (r = 0.989, p < 0.01).
#
# Table 1 Studies on hemispheric asymmetries, brain size, and neuron numbers that were included in the meta-regressions. Full size table
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      10)
# Out:
# Topic 10
#
# Top words:
# new, film, show, first, world, one, best, series, story, life, also, two, music, year, star, york, actor, black, movie, page
#
#
# Top documents:
# 1. Summer Movie Guide: What to watch from May through Labor Day
#
#
# More than 70 movies are coming to theaters and streaming at home this summer.
#
# Example video title will go here for this video
#
# Next up in 5
#
# NEW YORK — There is something for everyone at the movies this summer, both in theaters and streaming at home. In May, audiences can bid farewell to the Guardians of the Galaxy, go to Italy with Jane Fonda, Diane Keaton, Mary Steenburgen and Candice Bergen, or under the sea with Halle Bailey and Melissa McCarthy.
#
# June brings “Indiana Jones 5," a “Spider-Verse" sequel, “The Flash" a new Pixar pic and one film many have already called the best of the year ("Past Lives").
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      11)
# Out:
# Topic 11
#
# Top words:
# twitter, news, media, fox, said, social, musk, post, video, also, speech, transgender, online, wrote, white, content, users, people, company, cnn
#
#
# Top documents:
# 1. Twitter's Head of Content Moderation Resigns After Elon Musk Criticism
#
#
# A top Twitter executive responsible for safety and content moderation has left the company, her departure coming soon after owner Elon Musk publicly complained about the platform’s handling of posts about transgender topics.
#
# The departure pointed to a fresh wave of turmoil among key officials at Twitter since Musk took over last year.
#
# Ella Irwin, Twitter's head of trust and safety, confirmed her resignation in a pair of tweets late Friday. She did not say in the message why she was leaving, but her departure came shortly after Musk criticized Twitter’s handling of tweets about a conservative media company's documentary that questions transgender medical treatment for children and teens.
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      12)
# Out:
# Topic 12
#
# Top words:
# lgbtq, pride, community, said, drag, people, gay, city, trans, rights, queer, year, month, transgender, flag, event, anti, new, support, san
#
#
# Top documents:
# 1. San Francisco is naming the nation’s first drag laureate
#
#
# SAN FRANCISCO (AP) — Anti-trans legislation is roiling the nation. Bills prohibiting drag performances are cropping up in statehouses. Violence and vitriol are turning children’s drag story hour events into headline-news protests.
#
# San Francisco is fighting back Thursday by naming the nation’s first drag laureate, an ambassador-style position designed to represent the city’s famous LGBTQ+ community at a time when rights are under attack.
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      13)
# Out:
# Topic 13
#
# Top words:
# health, mental, study, also, said, patients, risk, people, women, may, research, medical, use, treatment, help, sex, suicide, care, social, new
#
#
# Top documents:
# 1. Maximize memory function with a nutrient-rich diet
#
#
# (TNS) Mayo Clinic News Network
#
# Research suggests that the ability to maximize memory function may be related to what you eat. Following an eating plan that provides a healthier selection of dietary fats and a variety of plant foods rich in phytonutrients could positively affect your health. Phytonutrients are substances found in certain plants that are believed to be beneficial for human health and help prevent certain diseases.
#
# There’s still much to learn about what makes up a brain-healthy diet. Studies are finding that what’s good for your heart also may be good for your brain. So the best bet for rich memories is to forgo unhealthy fat and remember to diversify your plant-based food portfolio.
#
# Foods that boost memory
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      14)
# Out:
# Topic 14
#
# Top words:
# people, right, one, even, political, many, american, black, white, anti, social, america, like, public, americans, power, left, new, history, movement
#
#
# Top documents:
# 1. THE FIVE ELEMENTS OF FASCISM
#
#
# And how Trump and much of today’s Republican Party embrace them
#
# ROBERT REICH
#
# JUN 15, 2023 (robertreich.substack.com)
#
# Friends,
#
# The Washington Post calls Trump’s vision for a second term “authoritarian.” That vision includes mandatory stop-and-frisk. Deploying the military to fight street crime, break up gangs, and deport immigrants. Purging the federal workforce and charging leakers.
#
# “In 2016, I declared I am your voice,” Trump said in a speech at the Conservative Political Action Conference and repeated at his first 2024 campaign rally in Waco, Texas. “Today, I add: I am your warrior. I am your justice. And for those who have been wronged and betrayed, I am your retribution.”
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      15)
# Out:
# Topic 15
#
# Top words:
# group, dodgers, said, sisters, catholic, anti, hate, church, night, pride, lgbtq, jewish, community, los, angeles, indulgence, perpetual, christian, faith, team
#
#
# Top documents:
# 1. Dodgers honor Sisters of Perpetual Indulgence at Pride Night that drew protests
#
#
# Protesters and supporters of a group of self-described "queer and trans nuns" gathered at Dodger Stadium during a LGBTQ+ Pride Night that followed weeks of high-profile controversy.
#
# The Pride Night event began about two hours before the first in a three-game series against the rival San Francisco Giants. The Dodgers have held Pride Nights for 10 years, but Friday's event came as debate continued over the team's plan to recognize the Sisters of Perpetual Indulgence with a Community Hero Award during the Pride Night celebration.
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      16)
# Out:
# Topic 16
#
# Top words:
# court, law, abortion, supreme, case, said, judge, federal, rights, decision, ruling, legal, lawsuit, religious, would, sex, discrimination, justice, state, states
#
#
# Top documents:
# 1. The Supreme Court rules for a designer who doesn't want to make wedding websites for gay couples
#
#
# WASHINGTON (AP) — In a defeat for gay rights, the Supreme Court’s conservative majority ruled on Friday that a Christian graphic artist who wants to design wedding websites can refuse to work with same-sex couples. One of the court’s liberal justices wrote in a dissent that the decision’s effect is to “mark gays and lesbians for second-class status” and that the decision opens the door to other discrimination.
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      17)
# Out:
# Topic 17
#
# Top words:
# using, cells, cell, min, used, performed, data, samples, analysis, protein, buffer, mice, two, per, rna, fig, gfp, dna, pbs, anti
#
#
# Top documents:
# 1. Lack of involvement of CD63 and CD9 tetraspanins in the extracellular vesicle content delivery process
#
#
# Cell culture
#
# HeLa cell (from ATCC, Virginia, USA) were cultured in DMEM (Gibco, Illinois, USA) complemented with 10% FBS (Biosera, France), at 37 °C 5% CO 2 . HeLa GFP-Hsp70 or NLuc-Hsp70 stable cell lines were selected with geneticin 10 μg/mL (Gibco, Illinois, USA) after lipofectamine-based transfection. CD63KO and CD9KO HeLa (gift from E Rubinstein and G Van Niel) cells were generated by CRISPR/Cas9 as described in8.
#
# Except mentioned otherwise, cells were transfected using Lipofectamine 2000 (Invitrogen, Massachusetts, USA), according to manufacturer’s protocol.
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      18)
# Out:
# Topic 18
#
# Top words:
# fig, supplementary, reaction, size, two, surface, also, energy, image, full, high, shown, using, structure, observed, different, mathrm, table, time, respectively
#
#
# Top documents:
# 1. Electrochemical chemo- and regioselective arylalkylation, dialkylation and hydro(deutero)alkylation of 1,3-enynes
#
#
# Reaction optimization of arylalkylation of 1,3-enynes
#
# ...

# %%
display_top_words_and_top_docs_for_specific_topic_ind(titles_and_texts,
                                                      topic_keys, 
                                                      topic_distributions,
                                                      19)
# Out:
# Topic 19
#
# Top words:
# new, year, million, said, market, china, also, government, would, state, company, ukraine, first, president, business, last, years, city, united, world
#
#
# Top documents:
# 1. TSX Venture Exchange Stock Maintenance Bulletins
#
#
# VANCOUVER, BC, April 3, 2023 /CNW/ -
#
# TSX VENTURE COMPANIES
#
# ALTINA CAPITAL CORP. ("ALTN.P")
#
# BULLETIN TYPE: Resume Trading
#
# BULLETIN DATE: April 3, 2023
#
# TSX Venture Tier 2 Company
#
# ...

# %% [markdown]
# In a very quick subjective skim by Pranav
#
# For K = 10:
# - 8 out of 10 seem coherent & meaningful.
# - 6 out of 10 seem to do with transgender discourse.
#
# For K = 20:
# - 17 out of 20 seem coherent & meaningful.
# - 12 out of 20 seem to do with transgender discourse.
